# %%
import pandas as pd
dfs = pd.read_html('https://rate.bot.com.tw/xrt?Lang=zh-TW')
currency = dfs[0]
# currency = currency.iloc[1] 
currency
# Out:
#                         幣別              現金匯率 Unnamed: 3_level_0    即期匯率  \
#         Unnamed: 0_level_1     本行買入     本行賣出               本行買入    本行賣出
# 0       美金 (USD)  美金 (USD)   30.305   30.995             30.675  30.775
# 1       港幣 (HKD)  港幣 (HKD)    3.748    3.964              3.884   3.944
# 2       英鎊 (GBP)  英鎊 (GBP)    38.38     40.5              39.38    39.8
# 3       澳幣 (AUD)  澳幣 (AUD)    22.17    22.95              22.44   22.67
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)    23.08    23.99              23.47   23.69
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)     21.9    22.81              22.39   22.57
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)    30.38    31.58              31.04   31.33
# 7       日圓 (JPY)  日圓 (JPY)    0.269   0.2818             0.2763  0.2803
# 8     南非幣 (ZAR)  南非幣 (ZAR)        -        -               2.09    2.17
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)     2.99     3.51               3.33    3.43
# 10      紐元 (NZD)  紐元 (NZD)    20.07    20.92              20.45   20.65
# ...
